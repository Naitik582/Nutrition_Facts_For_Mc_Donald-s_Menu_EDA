# %% [markdown]
# <a href="https://colab.research.google.com/github/Naitik582/Nutrition_Facts_For_Mc_Donald-s_Menu_EDA/blob/main/Nutrition_Facts_For_Mac_Donald's_Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40a92078-b512-427c-b50d-eb9155c9e07c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40a92078-b512-427c-b50d-eb9155c9e07c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print ("DATA CLEANING")
import pandas as pd

file_path = "menu.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
# DATA CLEANING
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
# ...

# %%
print ("Description Statistics")
df.describe(include='all')
# Out:
# Description Statistics
#             Category                                              Item  \
# count            260                                               260
# unique             9                                               260
# top     Coffee & Tea  McFlurry with Reese's Peanut Butter Cups (Snack)
# freq              95                                                 1
# mean             NaN                                               NaN
# std              NaN                                               NaN
# min              NaN                                               NaN
# 25%              NaN                                               NaN
# 50%              NaN                                               NaN
# 75%              NaN                                               NaN
# max              NaN                                               NaN
#
#         Serving Size     Calories  Calories from Fat   Total Fat  \
# ...

# %%
print ("Time Series Analysis")
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
df["Total Fat (% Daily Value)"].plot(marker="o", linestyle="-")
plt.title("Time Series Trend of Total Fat (% Daily Value)")
plt.xlabel("Date")
plt.ylabel("Total Fat (% DV)")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# Time Series Analysis

# %%
print ("Customer & Product Analysis")
import pandas as pd

file_path = "menu.csv"
df = pd.read_csv(file_path)

category_analysis = df.groupby("Category")[["Calories", "Total Fat", "Protein"]].mean()

print(category_analysis)
# Out:
# Customer & Product Analysis
#                       Calories  Total Fat    Protein
# Category
# Beef & Pork         494.000000  24.866667  27.333333
# Beverages           113.703704   0.092593   1.333333
# Breakfast           526.666667  27.690476  19.857143
# Chicken & Fish      552.962963  26.962963  29.111111
# Coffee & Tea        283.894737   8.021053   8.863158
# Desserts            222.142857   7.357143   4.000000
# Salads              270.000000  11.750000  19.833333
# Smoothies & Shakes  531.428571  14.125000  10.857143
# Snacks & Sides      245.769231  10.538462   8.384615

# %%
print ("Data Visualization")
import pandas as pd
import matplotlib.pyplot as plt

file_path = "menu.csv"
df = pd.read_csv(file_path)

category_analysis = df.groupby("Category")[["Calories", "Total Fat", "Protein"]].mean()

category_analysis.plot(kind="bar", figsize=(12, 6))
plt.title("Category-wise Average Nutritional Values")
plt.xlabel("Category")
plt.ylabel("Average Value")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.legend(title="Nutrients")
plt.show()
# Out:
# Data Visualization

# %%
print ("Breakdown Of Data Visualization")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "menu.csv"
df = pd.read_csv(file_path)

sns.set_style("whitegrid")

# 1. **Calories Distribution**
plt.figure(figsize=(10, 5))
sns.histplot(df["Calories"], bins=20, kde=True, color="blue")
plt.title("Distribution of Calories")
plt.xlabel("Calories")
plt.ylabel("Frequency")
plt.show()

# 2. **Category-wise Calories**
plt.figure(figsize=(12, 6))
sns.boxplot(x="Category", y="Calories", data=df, palette="Set2")
plt.title("Calories Distribution Across Categories")
plt.xticks(rotation=45)
plt.show()

# 3. **Correlation Heatmap**
plt.figure(figsize=(10, 6))
sns.heatmap(df[["Calories", "Total Fat", "Saturated Fat", "Cholesterol", "Sodium", "Carbohydrates", "Protein"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap of Nutritional Values")
plt.show()

# 4. **Total Fat vs Calories**
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Total Fat", y="Calories", data=df, color="red")
plt.title("Total Fat vs Calories")
plt.xlabel("Total Fat (g)")
plt.ylabel("Calories")
plt.show()

# 5. **Category Count Plot**
plt.figure(figsize=(10, 5))
sns.countplot(y="Category", data=df, palette="viridis")
plt.title("Count of Items in Each Category")
plt.xlabel("Count")
plt.ylabel("Category")
plt.show()
# Out:
# Breakdown Of Data Visualization
# <ipython-input-19-690bc0bfdf27>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Category", y="Calories", data=df, palette="Set2")
# <ipython-input-19-690bc0bfdf27>:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Category", data=df, palette="viridis")

# %%
from IPython.display import display, Markdown

# Recommendations
recommendations = [
    "**1. Calories:** Some items go up to **1880 kcal**. Pick lower-calorie options like **Egg White Delight (250 kcal)** if watching weight.",
    "**2. Fat:** Some meals have **1000+ kcal from fat**. Avoid high-fat foods and pick ones with **less than 20g fat**.",
    "**3. Saturated & Trans Fat:** Bad for the heart. Choose meals with **less than 5g saturated fat** and **zero trans fat**.",
    "**4. Carbs & Sugar:** Some items have **140g carbs** and **128g sugar**. Avoid high sugar foods, aim for **below 30g sugar**.",
    "**5. Protein:** More than **20g protein** is good for muscles. Choose high-protein options.",
    "**6. Vitamins & Minerals:** Some meals have **high Vitamin A & Calcium**—good for bones & immunity.",
    "**7. Iron:** Pick meals with **at least 15% iron** for better energy levels."
]

# Key Findings
key_findings = [
    "**1. Healthiest Choices:** Egg White Delight, Grilled Chicken (**low fat, high protein**).",
    "**2. Unhealthy Choices:** Large Burgers, Fries, Milkshakes (**high fat, sugar, and calories**).",
    "**3. For Weight Loss:** Eat **low-calorie, high-protein** meals like salads & grilled food.",
    "**4. For Muscle Gain:** Go for **high-protein items** like Sausage McMuffin with Egg.",
    "**5. For Heart Health:** Avoid **fried & high-fat foods**. Prefer grilled items.",
    "**6. For Diabetes:** Choose **low-sugar, high-fiber** meals like salads & protein-rich options."
]

display(Markdown("### **Recommendations** ###\n"))
for rec in recommendations:
    display(Markdown(rec))

display(Markdown("\n### **Key Findings** ###\n"))
for key in key_findings:
    display(Markdown(key))

display(Markdown("\n### **Conclusion:** Fast food can fit in a healthy diet if chosen wisely. Go for **grilled, low-fat, and high-protein** options, and avoid **high-sugar, high-fat foods.**"))
# Out:
# ### **Recommendations** ###
# **1. Calories:** Some items go up to **1880 kcal**. Pick lower-calorie options like **Egg White Delight (250 kcal)** if watching weight.
# **2. Fat:** Some meals have **1000+ kcal from fat**. Avoid high-fat foods and pick ones with **less than 20g fat**.
# **3. Saturated & Trans Fat:** Bad for the heart. Choose meals with **less than 5g saturated fat** and **zero trans fat**.
# **4. Carbs & Sugar:** Some items have **140g carbs** and **128g sugar**. Avoid high sugar foods, aim for **below 30g sugar**.
# **5. Protein:** More than **20g protein** is good for muscles. Choose high-protein options.
# **6. Vitamins & Minerals:** Some meals have **high Vitamin A & Calcium**—good for bones & immunity.
# **7. Iron:** Pick meals with **at least 15% iron** for better energy levels.
# ### **Key Findings** ###
# **1. Healthiest Choices:** Egg White Delight, Grilled Chicken (**low fat, high protein**).
# ...
